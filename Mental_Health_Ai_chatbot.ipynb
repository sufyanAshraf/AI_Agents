# %% [markdown]
# <a href="https://colab.research.google.com/github/sufyanAshraf/AI_Agents/blob/main/Mental_Health_Ai_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mental Health

# %%
# !pip install -q langchain_groq
# !pip install -q langchain_community
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.8/130.8 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 34.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.2 MB/s eta 0:00:00

# %%
# !pip install -q jupyter_bokeh

# %%
from groq import Groq
from langchain_groq import ChatGroq

from langchain_core.prompts import ChatPromptTemplate, HumanMessagePromptTemplate, MessagesPlaceholder
from langchain_core.messages import SystemMessage
from google.colab import userdata

# %%
# userdata.get('LANGCHAIN_API_KEY')
# userdata.get('GROQ_API_KEY')

# %%
llm=ChatGroq(groq_api_key=userdata.get('GROQ_API_KEY'),
         model_name="llama3-8b-8192")

# %%
def get_completion_from_messages(messages,llm): # Andrew mentioned that the prompt/ completion paradigm is preferable for this class
    system_prompt = "You are Dr. Evans a world class mental health doctor."
    messages_with_system = [{'role': 'system', 'content': system_prompt}] + messages
    response = llm.invoke(messages_with_system)
    return response.content

# %%
def collect_messages(_):
    global llm
    prompt = inp.value_input
    inp.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context, llm)
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=625), styles={'background-color': '#F16666'}))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600), styles={'background-color': '#F6F6F6'}))

    return pn.Column(*panels)

# %%
import os
from dotenv import load_dotenv, find_dotenv

# %%
import panel as pn  # GUI
pn.extension()

panels = [] # collect display

context = [ {'role':'system', 'content':"""
In the last session, Oliver shares with me (Dr. Evans) that he has been feeling overwhelmed by work, relationships, and daily tasks, often struggling with self-doubt and comparison to others. He describes experiencing racing thoughts, difficulty focusing, and emotional shutdowns when stress builds up. Dr. Evans validates his feelings and explores possible triggers, such as social comparison, while encouraging him to identify coping strategies. Although Oliver admits he tried journaling but didn’t stick with it, Dr. Evans reassures him that finding the right techniques takes time and suggests grounding exercises and small, manageable goals to reduce his anxiety. Oliver expresses frustration but also hope, appreciating the support. Dr. Evans emphasizes that healing is a gradual process and reinforces that Oliver is not alone in his struggles, ending the session on a collaborative and reassuring note.

context: ask a question to the patient and help that patient. be a professional doctor. Do not explain anything. Just ask questions and analyse his answer, and ask questions based on his answers. 1 question at a time
for the first question tell oliver what we discuss last time and ask a relevant question.
Task: Ask relevant question

"""} ]  # accumulate messages


inp = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…', width=600, height=50)
button_conversation = pn.widgets.Button(name="Chat!")

interactive_conversation = pn.bind(collect_messages, button_conversation)

dashboard = pn.Column(
    pn.Row(inp, button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True, height=300),
)

dashboard
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a7709539-580c-4267-827b-bc48793de2d2'>
#   <div id="df32e4bf-8ae6-4112-bb86-f357c1d58a31" data-root-id="a7709539-580c-4267-827b-bc48793de2d2" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# # check response only (old pro)

# %%
messages =  context.copy()
messages.append(
{'role':'system', 'content':'create a json summary of the previous food order. Itemize the price for each item\
 The fields should be 1) pizza, include size 2) list of toppings 3) list of drinks, include size   4) list of sides include size  5)total price '},
)
 #The fields should be 1) pizza, price 2) list of toppings 3) list of drinks, include size include price  4) list of sides include size include price, 5)total price '},

response = get_completion_from_messages(messages, llm)
print(response)
# Out:
#  Is it a specific project, a new role, or something else entirely?
